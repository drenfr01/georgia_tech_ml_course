# %%
import pandas as pd

# %%
import pandas as pd

# %%
df = pd.read_csv('training.csv', parse_dates=['PurchDate'])

# %%
df.head().transpose()
# Out:
#                                                      0                    1  \
# RefId                                                1                    2
# IsBadBuy                                             0                    0
# PurchDate                          2009-12-07 00:00:00  2009-12-07 00:00:00
# Auction                                          ADESA                ADESA
# VehYear                                           2006                 2004
# VehicleAge                                           3                    5
# Make                                             MAZDA                DODGE
# Model                                           MAZDA3  1500 RAM PICKUP 2WD
# Trim                                                 i                   ST
# SubModel                                    4D SEDAN I    QUAD CAB 4.7L SLT
# Color                                              RED                WHITE
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72983 entries, 0 to 72982
# Data columns (total 34 columns):
# RefId                                72983 non-null int64
# IsBadBuy                             72983 non-null int64
# PurchDate                            72983 non-null datetime64[ns]
# Auction                              72983 non-null object
# VehYear                              72983 non-null int64
# VehicleAge                           72983 non-null int64
# Make                                 72983 non-null object
# Model                                72983 non-null object
# Trim                                 70623 non-null object
# SubModel                             72975 non-null object
# Color                                72975 non-null object
# Transmission                         72974 non-null object
# WheelTypeID                          69814 non-null float64
# WheelType                            69809 non-null object
# ...

# %%
df['Model'].nunique()
# Out:
# 1063

# %%
df['WheelTypeID'].value_counts()
# Out:
# 1.0    36050
# 2.0    33004
# 3.0      755
# 0.0        5
# Name: WheelTypeID, dtype: int64

# %%
df['IsBadBuy'].value_counts()
# Out:
# 0    64007
# 1     8976
# Name: IsBadBuy, dtype: int64
